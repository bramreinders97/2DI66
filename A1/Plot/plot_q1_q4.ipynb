# %%
import matplotlib.pyplot as plt

def plot_confidence_interval(x, prob, ci, color='#2187bb', horizontal_line_width=0.25):

    left = x - horizontal_line_width / 2
    right = x + horizontal_line_width / 2
    plt.plot([x,x], [ci[0], ci[1]], color=color)
    plt.plot([left, right], [ci[0], ci[0]], color=color)
    plt.plot([left, right], [ci[1], ci[1]], color=color)
    plt.plot(x, prob, '.', color='#f44336')

# %%
def create_plots_with_draw(white_prob, white_ci, black_prob, black_ci, draw_prob, draw_ci, Q):
    plt.xticks([1, 2, 3], ['White', 'Black', 'Draw'])
    plt.title(f"Win probabilities Q{Q}")
    plot_confidence_interval(1, white_prob, white_ci)
    plot_confidence_interval(2, black_prob, black_ci)
    plot_confidence_interval(3, draw_prob, draw_ci)
    plt.show()

def create_plots_no_draw(white_prob, white_ci, black_prob, black_ci, Q):
    plt.xticks([1, 2], ['White', 'Black'])
    plt.title(f"Win probabilities Q{Q}")
    plot_confidence_interval(1, white_prob, white_ci)
    plot_confidence_interval(2, black_prob, black_ci)
    plt.show()

# %% [markdown]
# Make plots Q1 (before col switch fix)

# %%
white_prob = 0.349
white_ci = (0.3460456681323859, 0.35195433186761405)

black_prob = 0.3646
black_ci = (0.36161676126911707, 0.3675832387308829)

draw_prob = 0.2864
draw_ci = (0.2835979879485198, 0.28920201205148016)

create_plots_with_draw(white_prob, white_ci, black_prob, black_ci, draw_prob, draw_ci, 1)

# %% [markdown]
# Make plots Q4 (before col switch fix)

# %%
white_prob = 0.34057
white_ci = (0.33763273171177, 0.34350726828822997)

black_prob = 0.36691
black_ci = (0.36392277061714534, 0.3698972293828547)

draw_prob = 0.29252
draw_ci = (0.28970037769596113, 0.2953396223040389)

create_plots_with_draw(white_prob, white_ci, black_prob, black_ci, draw_prob, draw_ci, 4)

# %% [markdown]
# Make plots Q1 (after col switch fix and after pawn promote fix)

# %%
white_prob = 0.08823
white_ci = (0.08647204861724973, 0.08998795138275027)

black_prob = 0.1008
black_ci = (0.09893398776698543, 0.10266601223301457)

draw_prob = 0.81097
draw_ci = (0.8085432567354609, 0.813396743264539)

create_plots_with_draw(white_prob, white_ci, black_prob, black_ci, draw_prob, draw_ci, 1)
create_plots_no_draw(white_prob, white_ci, black_prob, black_ci, 1)

# %% [markdown]
# Make plots Q4 (after col switch fix and after pawn promote fix)

# %%
white_prob = 0.08758
white_ci = (0.08582791190000685, 0.08933208809999316)

black_prob = 0.10077
black_ci = (0.09890423434506002, 0.10263576565493998)

draw_prob = 0.81165
draw_ci = (0.8092266101748914, 0.8140733898251086)

create_plots_with_draw(white_prob, white_ci, black_prob, black_ci, draw_prob, draw_ci, 4)
create_plots_no_draw(white_prob, white_ci, black_prob, black_ci, 4)
